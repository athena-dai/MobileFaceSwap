# %%
from cleanfid import fid
import glob
from PIL import Image
import torch
import os 

fake_image_path = "/Users/athenadai/Desktop/MobileFaceSwap/results"
print(fake_image_path)

real_image_path = "/Users/athenadai/Desktop/MobileFaceSwap/source_images"
print(real_image_path)

fid_score = fid.compute_fid(fake_image_path, real_image_path)

print("\n FID Score:", fid_score)
# Out:
# /Users/athenadai/Desktop/MobileFaceSwap/results
# /Users/athenadai/Desktop/MobileFaceSwap/source_images
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[13], line 13
#      10 real_image_path = "/Users/athenadai/Desktop/MobileFaceSwap/source_images"
#      11 print(real_image_path)
# ---> 13 fid_score = fid.compute_fid(fake_image_path, real_image_path)
#      15 print("\n FID Score:", fid_score)
#
# File ~/anaconda3/envs/idl-project/lib/python3.9/site-packages/cleanfid/fid.py:465, in compute_fid(fdir1, fdir2, gen, mode, model_name, num_workers, batch_size, device, dataset_name, dataset_res, dataset_split, num_gen, z_dim, custom_feat_extractor, verbose, custom_image_tranform, custom_fn_resize, use_dataparallel)
#     457 def compute_fid(fdir1=None, fdir2=None, gen=None,
#     458             mode="clean", model_name="inception_v3", num_workers=12,
# ...
